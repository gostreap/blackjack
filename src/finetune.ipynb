# %%
from q_learning import QLearning
from sarsa import Sarsa
from temporal_difference import TemporalDifference

# %%
best_espilon, best_gamma, best_reward = None, None, -1000
for epsilon in [0.001, 0.01, 0.1, 0.2, 0.3, 0.5]:
    for gamma in [1 / i for i in range(1, 8)]:
        print("#### {} {} ####".format(epsilon, gamma))
        model = QLearning("v1", epsilon=epsilon, gamma=gamma)
        model.train(40000)
        _, _, _, reward = model.test(10000)
        if reward > best_reward:
            best_reward = reward
            best_espilon = epsilon
            best_gamma = gamma
print(best_espilon, best_gamma, best_reward)
# Out:
# #### 0.001 1.0 ####
# training, episode 0 out of 40000
# training, episode 10000 out of 40000
# training, episode 20000 out of 40000
# training, episode 30000 out of 40000
# win: 0.3671 | draw: 0.0773 | loss: 0.5556
# mean reward: -0.1885
# #### 0.001 0.5 ####
# training, episode 0 out of 40000
# training, episode 10000 out of 40000
# training, episode 20000 out of 40000
# training, episode 30000 out of 40000
# win: 0.392 | draw: 0.0903 | loss: 0.5177
# mean reward: -0.1257
# #### 0.001 0.3333333333333333 ####
# training, episode 0 out of 40000
# training, episode 10000 out of 40000
# training, episode 20000 out of 40000
# training, episode 30000 out of 40000
# win: 0.4054 | draw: 0.0804 | loss: 0.5142
# mean reward: -0.1088
# #### 0.001 0.25 ####
# training, episode 0 out of 40000
# training, episode 10000 out of 40000
# training, episode 20000 out of 40000
# training, episode 30000 out of 40000
# win: 0.3926 | draw: 0.0856 | loss: 0.5218
# mean reward: -0.1292
# #### 0.001 0.2 ####
# training, episode 0 out of 40000
# training, episode 10000 out of 40000
# training, episode 20000 out of 40000
# training, episode 30000 out of 40000
# win: 0.4109 | draw: 0.0915 | loss: 0.4976
# mean reward: -0.0867
# #### 0.001 0.16666666666666666 ####
# training, episode 0 out of 40000
# training, episode 10000 out of 40000
# training, episode 20000 out of 40000
# training, episode 30000 out of 40000
# win: 0.4076 | draw: 0.0925 | loss: 0.4999
# mean reward: -0.0923
# #### 0.001 0.14285714285714285 ####
# training, episode 0 out of 40000
# training, episode 10000 out of 40000
# training, episode 20000 out of 40000
# training, episode 30000 out of 40000
# win: 0.3908 | draw: 0.0802 | loss: 0.529
# mean reward: -0.1382
# #### 0.01 1.0 ####
# training, episode 0 out of 40000
# training, episode 10000 out of 40000
# training, episode 20000 out of 40000
# training, episode 30000 out of 40000
# win: 0.3979 | draw: 0.0825 | loss: 0.5196
# mean reward: -0.1217
# #### 0.01 0.5 ####
# training, episode 0 out of 40000
# training, episode 10000 out of 40000
# training, episode 20000 out of 40000
# training, episode 30000 out of 40000
# win: 0.4002 | draw: 0.0919 | loss: 0.5079
# mean reward: -0.1077
# #### 0.01 0.3333333333333333 ####
# training, episode 0 out of 40000
# training, episode 10000 out of 40000
# training, episode 20000 out of 40000
# training, episode 30000 out of 40000
# win: 0.4072 | draw: 0.0879 | loss: 0.5049
# mean reward: -0.0977
# #### 0.01 0.25 ####
# training, episode 0 out of 40000
# training, episode 10000 out of 40000
# training, episode 20000 out of 40000
# training, episode 30000 out of 40000
# win: 0.4089 | draw: 0.0876 | loss: 0.5035
# mean reward: -0.0946
# #### 0.01 0.2 ####
# training, episode 0 out of 40000
# training, episode 10000 out of 40000
# training, episode 20000 out of 40000
# training, episode 30000 out of 40000
# win: 0.3924 | draw: 0.0835 | loss: 0.5241
# mean reward: -0.1317
# #### 0.01 0.16666666666666666 ####
# training, episode 0 out of 40000
# training, episode 10000 out of 40000
# training, episode 20000 out of 40000
# training, episode 30000 out of 40000
# win: 0.414 | draw: 0.0885 | loss: 0.4975
# mean reward: -0.0835
# #### 0.01 0.14285714285714285 ####
# training, episode 0 out of 40000
# training, episode 10000 out of 40000
# training, episode 20000 out of 40000
# training, episode 30000 out of 40000
# win: 0.4167 | draw: 0.0914 | loss: 0.4919
# mean reward: -0.0752
# #### 0.1 1.0 ####
# training, episode 0 out of 40000
# training, episode 10000 out of 40000
# training, episode 20000 out of 40000
# training, episode 30000 out of 40000
# win: 0.3733 | draw: 0.0743 | loss: 0.5524
# mean reward: -0.1791
# #### 0.1 0.5 ####
# training, episode 0 out of 40000
# training, episode 10000 out of 40000
# training, episode 20000 out of 40000
# training, episode 30000 out of 40000
# win: 0.4141 | draw: 0.0975 | loss: 0.4884
# mean reward: -0.0743
# #### 0.1 0.3333333333333333 ####
# training, episode 0 out of 40000
# training, episode 10000 out of 40000
# training, episode 20000 out of 40000
# training, episode 30000 out of 40000
# win: 0.4304 | draw: 0.0968 | loss: 0.4728
# mean reward: -0.0424
# #### 0.1 0.25 ####
# training, episode 0 out of 40000
# training, episode 10000 out of 40000
# training, episode 20000 out of 40000
# training, episode 30000 out of 40000
# win: 0.4254 | draw: 0.0957 | loss: 0.4789
# mean reward: -0.0535
# #### 0.1 0.2 ####
# training, episode 0 out of 40000
# training, episode 10000 out of 40000
# training, episode 20000 out of 40000
# training, episode 30000 out of 40000
# win: 0.4187 | draw: 0.0932 | loss: 0.4881
# mean reward: -0.0694
# #### 0.1 0.16666666666666666 ####
# training, episode 0 out of 40000
# training, episode 10000 out of 40000
# training, episode 20000 out of 40000
# training, episode 30000 out of 40000
# win: 0.4359 | draw: 0.0961 | loss: 0.468
# mean reward: -0.0321
# #### 0.1 0.14285714285714285 ####
# training, episode 0 out of 40000
# training, episode 10000 out of 40000
# training, episode 20000 out of 40000
# training, episode 30000 out of 40000
# win: 0.4356 | draw: 0.0862 | loss: 0.4782
# mean reward: -0.0426
# #### 0.2 1.0 ####
# training, episode 0 out of 40000
# training, episode 10000 out of 40000
# training, episode 20000 out of 40000
# training, episode 30000 out of 40000
# win: 0.3815 | draw: 0.0806 | loss: 0.5379
# mean reward: -0.1564
# #### 0.2 0.5 ####
# training, episode 0 out of 40000
# training, episode 10000 out of 40000
# training, episode 20000 out of 40000
# training, episode 30000 out of 40000
# win: 0.4153 | draw: 0.0976 | loss: 0.4871
# mean reward: -0.0718
# #### 0.2 0.3333333333333333 ####
# training, episode 0 out of 40000
# training, episode 10000 out of 40000
# training, episode 20000 out of 40000
# training, episode 30000 out of 40000
# win: 0.4209 | draw: 0.0919 | loss: 0.4872
# mean reward: -0.0663
# #### 0.2 0.25 ####
# training, episode 0 out of 40000
# training, episode 10000 out of 40000
# training, episode 20000 out of 40000
# training, episode 30000 out of 40000
# win: 0.4241 | draw: 0.0948 | loss: 0.4811
# mean reward: -0.057
# #### 0.2 0.2 ####
# training, episode 0 out of 40000
# training, episode 10000 out of 40000
# training, episode 20000 out of 40000
# training, episode 30000 out of 40000
# win: 0.4301 | draw: 0.0985 | loss: 0.4714
# mean reward: -0.0413
# #### 0.2 0.16666666666666666 ####
# training, episode 0 out of 40000
# training, episode 10000 out of 40000
# training, episode 20000 out of 40000
# training, episode 30000 out of 40000
# win: 0.4155 | draw: 0.0944 | loss: 0.4901
# mean reward: -0.0746
# #### 0.2 0.14285714285714285 ####
# training, episode 0 out of 40000
# training, episode 10000 out of 40000
# training, episode 20000 out of 40000
# training, episode 30000 out of 40000
# win: 0.4286 | draw: 0.0971 | loss: 0.4743
# mean reward: -0.0457
# #### 0.3 1.0 ####
# training, episode 0 out of 40000
# training, episode 10000 out of 40000
# training, episode 20000 out of 40000
# training, episode 30000 out of 40000
# win: 0.3821 | draw: 0.0748 | loss: 0.5431
# mean reward: -0.161
# #### 0.3 0.5 ####
# training, episode 0 out of 40000
# training, episode 10000 out of 40000
# training, episode 20000 out of 40000
# training, episode 30000 out of 40000
# win: 0.4152 | draw: 0.0937 | loss: 0.4911
# mean reward: -0.0759
# #### 0.3 0.3333333333333333 ####
# training, episode 0 out of 40000
# training, episode 10000 out of 40000
# training, episode 20000 out of 40000
# training, episode 30000 out of 40000
# win: 0.4195 | draw: 0.0893 | loss: 0.4912
# mean reward: -0.0717
# #### 0.3 0.25 ####
# training, episode 0 out of 40000
# training, episode 10000 out of 40000
# training, episode 20000 out of 40000
# training, episode 30000 out of 40000
# win: 0.4237 | draw: 0.0932 | loss: 0.4831
# mean reward: -0.0594
# #### 0.3 0.2 ####
# training, episode 0 out of 40000
# training, episode 10000 out of 40000
# training, episode 20000 out of 40000
# training, episode 30000 out of 40000
# win: 0.4257 | draw: 0.0908 | loss: 0.4835
# mean reward: -0.0578
# #### 0.3 0.16666666666666666 ####
# training, episode 0 out of 40000
# training, episode 10000 out of 40000
# training, episode 20000 out of 40000
# training, episode 30000 out of 40000
# win: 0.4231 | draw: 0.0933 | loss: 0.4836
# mean reward: -0.0605
# #### 0.3 0.14285714285714285 ####
# training, episode 0 out of 40000
# training, episode 10000 out of 40000
# training, episode 20000 out of 40000
# training, episode 30000 out of 40000
# win: 0.4287 | draw: 0.0898 | loss: 0.4815
# mean reward: -0.0528
# #### 0.5 1.0 ####
# training, episode 0 out of 40000
# training, episode 10000 out of 40000
# training, episode 20000 out of 40000
# training, episode 30000 out of 40000
# win: 0.3816 | draw: 0.0794 | loss: 0.539
# mean reward: -0.1574
# #### 0.5 0.5 ####
# training, episode 0 out of 40000
# training, episode 10000 out of 40000
# training, episode 20000 out of 40000
# training, episode 30000 out of 40000
# win: 0.416 | draw: 0.0956 | loss: 0.4884
# mean reward: -0.0724
# #### 0.5 0.3333333333333333 ####
# training, episode 0 out of 40000
# training, episode 10000 out of 40000
# training, episode 20000 out of 40000
# training, episode 30000 out of 40000
# win: 0.426 | draw: 0.0995 | loss: 0.4745
# mean reward: -0.0485
# #### 0.5 0.25 ####
# training, episode 0 out of 40000
# training, episode 10000 out of 40000
# training, episode 20000 out of 40000
# training, episode 30000 out of 40000
# win: 0.4201 | draw: 0.0988 | loss: 0.4811
# mean reward: -0.061
# #### 0.5 0.2 ####
# training, episode 0 out of 40000
# training, episode 10000 out of 40000
# training, episode 20000 out of 40000
# training, episode 30000 out of 40000
# win: 0.4298 | draw: 0.101 | loss: 0.4692
# mean reward: -0.0394
# #### 0.5 0.16666666666666666 ####
# training, episode 0 out of 40000
# training, episode 10000 out of 40000
# training, episode 20000 out of 40000
# training, episode 30000 out of 40000
# win: 0.427 | draw: 0.0935 | loss: 0.4795
# mean reward: -0.0525
# #### 0.5 0.14285714285714285 ####
# training, episode 0 out of 40000
# training, episode 10000 out of 40000
# training, episode 20000 out of 40000
# training, episode 30000 out of 40000
# win: 0.4269 | draw: 0.0881 | loss: 0.485
# mean reward: -0.0581
# 0.5 0.14285714285714285 -1000
